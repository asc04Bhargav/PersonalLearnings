# %%
from langchain_helper import generate_sql_query, execute_sql_query

# Test LLM-based SQL generation
user_query = "How many white Adidas T-shirts are left in stock?"
sql_query = generate_sql_query(user_query)
print("Generated SQL Query:", sql_query)

# Test database connection
result = execute_sql_query(sql_query)
print("Query Result:", result)
# Out:
# Running cells with 'Python 3.12.8' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/bhargav.veerabommala/AppData/Local/Microsoft/WindowsApps/python3.12.exe -m pip install ipykernel -U --user --force-reinstall'
